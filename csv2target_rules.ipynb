# %% [markdown]
# csv to target_rules

# %%
import csv
row_all=[]
with open('KB/socialIsolationTerms_simple_042118.csv') as csvfile:
    csv_file = csv.reader(csvfile, delimiter=',')
    for row in csv_file:
        #print(row[0]+ " --- " +row[1])
        row_all.append(row)
print(len(row_all))

rules1=[]
for row in row_all:
    rules1.append("Comments: ''")
    rules1.append("Direction: ''")
    rules1.append("Lex: "+ row[1])
    rules1.append("Regex: "+ row[0])
    rules1.append("Type: ISOLATION")
    rules1.append("---")

print(len(rules1))
rules='\n'.join(rules1)
print(rules)
        
with open('KB/social_target_rules_042118.yml', 'w') as f:
    f.write(rules)
# Out:
# 116
# 696
# Comments: ''
# Direction: ''
# Lex: autism
# Regex: autism
# Type: ISOLATION
# ---
# Comments: ''
# Direction: ''
# Lex: afraid people will judge him
# Regex: afraid (people|.{1,20})? will judge (me|her|him)
# Type: ISOLATION
# ---
# Comments: ''
# Direction: ''
# Lex: asked to leave group
# Regex: asked to leave (group)?
# Type: ISOLATION
# ---
# Comments: ''
# Direction: ''
# Lex: avoid family
# Regex: (avoid\w?|avoided|avoiding) family
# Type: ISOLATION
# ---
# Comments: ''
# Direction: ''
# Lex: avoidance as a coping skill
# Regex: avoidance as a coping skill
# Type: ISOLATION
# ---
# Comments: ''
# Direction: ''
# Lex: be abandoned
# Regex: (be|been|am|was|is|\'s).{1,20} abandoned
# Type: ISOLATION
# ---
# Comments: ''
# Direction: ''
# Lex: be homeless
# Regex: (be|been|am|was|is|\'s) homeless
# Type: ISOLATION
# ---
# Comments: ''
# Direction: ''
# Lex: be isolating
# Regex: (be|been|am|is|was) isolating
# Type: ISOLATION
# ---
# Comments: ''
# Direction: ''
# ...
